# %% [markdown]
# Example notebook to set up binder
#
# Plotting example taken from [R for Data Science: Chapter 3 - Data Visualisation](https://r4ds.had.co.nz/data-visualisation.html)

# %%
library(tidyverse)

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = class))
# Out:
# plot without title
